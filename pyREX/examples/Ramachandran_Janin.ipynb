# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import MDAnalysis as mda
import pyREX.core as core
import pyREX.misc as misc
import pyREX.dihedrals as dih

# %%
pdb = "./../tests/2hba_ChainB_ref.pdb"
xtc = "./../tests/traj2.xtc"
u = mda.Universe(pdb, xtc)
u
tv = core.iPlayer(u)
tv()
# Out:
# /home/arthur/.local/lib/python3.6/site-packages/MDAnalysis/topology/guessers.py:80: UserWarning: Failed to guess the mass for the following atom types:
#   warnings.warn("Failed to guess the mass for the following atom types: {}".format(atom_type))
# /home/arthur/.local/lib/python3.6/site-packages/MDAnalysis/topology/PDBParser.py:330: UserWarning: Element information is absent or missing for a few atoms. Elements attributes will not be populated.
#   warnings.warn("Element information is absent or missing for a few "
# VBox(children=(NGLWidget(count=11), HBox(children=(Button(description='Time: 0 ps', style=ButtonStyle(), toolt…

# %%
rama1 = dih.get_ramachandran(u)
# Out:
# <img src="data:image/png;base64,..." width="650">

# %%
rama2 = dih.get_ramachandran(u, stop=2)
# Out:
# <img src="data:image/png;base64,..." width="650">

# %%
phi = dih.get_phi_values(u, sel="protein and resid 1-3")
psi = dih.get_psi_values(u, sel="protein and resid 1-3")
omega = dih.get_omega_values(u, sel="protein and resid 1-3")

# %%
misc.cprint("phi:", "red")
print(phi)
misc.cprint("psi:", "red")
print(psi)
misc.cprint("pomega:", "red")
print(omega)
# Out:
# phi:
# [[ -94.2490958  -134.11856567]
#  [-110.23810348 -114.73882534]
#  [-105.13546359 -138.15410111]
#  [-122.06210013 -133.04477618]
#  [-119.56792367 -129.31586744]
#  [ -94.92033282 -120.18167459]
#  [ -94.27295596 -132.16497409]
#  [ -79.20200857 -138.68128306]
#  [ -92.26701595 -127.99439762]
#  [-101.78741148 -120.21520201]
#  [ -74.85224889 -134.64247084]]
# psi:
# [[126.03882313 128.28423016 158.29186853]
#  [138.1825682  110.88308993 152.0172139 ]
#  [121.61253977 129.50685931 143.54997724]
#  [135.0275584  133.24723501 156.43369587]
#  [129.03280806 126.32014729 165.06812511]
#  [105.95607503 119.32972563 156.59393905]
#  [ 96.62738319 125.47456009 160.42849968]
#  [ 98.44885433 132.75299845 151.23780926]
#  [129.85808698 122.19026682 153.17069498]
#  [120.61507518 118.3726969  165.74201468]
#  [106.4755152  118.43500008 141.66574543]]
# pomega:
# [[ 166.07854747 -168.48971509  168.465176  ]
#  [ 179.96646465 -178.9298094   159.63263319]
#  [ 175.20714092 -164.60814406  169.68803978]
#  [ 175.60777915 -157.6769568   169.76349669]
#  [ 179.45040114 -161.41081642  157.24519225]
#  [ 175.54197865 -169.37907146  169.64367521]
#  [-175.38039283 -168.2847036   165.45976722]
#  [ 170.05993795 -171.44121217  171.6536755 ]
#  [ 175.83927468  174.2206444   170.00674857]
#  [-176.90392587 -179.71492916  171.26724052]
#  [ 178.93421862 -172.16276008 -177.76040134]]

# %%
janin = dih.get_janin(u)
# Out:
# <img src="data:image/png;base64,..." width="650">
# All ALA, CYS, GLY, PRO, SER, THR, and VAL residues have been removed from the selection.

# %%
janin = dih.get_janin(u, stop=1)
# Out:
# <img src="data:image/png;base64,..." width="650">
# All ALA, CYS, GLY, PRO, SER, THR, and VAL residues have been removed from the selection.

# %%
chi1 = dih.get_chi1_values(u, sel="protein and resid 1-4")
chi2 = dih.get_chi1_values(u, sel="protein and resid 1-4", verbose=False)

misc.cprint("chi1:", "red")
print(chi1)
misc.cprint("chi2:", "red")
print(chi2)
# Out:
# All ALA, CYS, GLY, PRO, SER, THR, and VAL residues have been removed from the selection.
# chi1:
# [[-160.68861291 -178.47077973]
#  [ 176.78476    -163.69936913]
#  [ 169.03763188 -174.71404488]
#  [ 159.95142785 -165.71267245]
#  [ 170.01884351 -170.94478312]
#  [ 171.19904793 -172.09902049]
#  [ 178.68796906 -164.21240099]
#  [ 164.87521108 -160.61967196]
#  [ 179.28584175 -158.59478586]
#  [-168.84725242  174.93284297]
#  [-175.12381231 -162.49440322]]
# chi2:
# [[-160.68861291 -178.47077973]
#  [ 176.78476    -163.69936913]
#  [ 169.03763188 -174.71404488]
#  [ 159.95142785 -165.71267245]
#  [ 170.01884351 -170.94478312]
#  [ 171.19904793 -172.09902049]
#  [ 178.68796906 -164.21240099]
#  [ 164.87521108 -160.61967196]
#  [ 179.28584175 -158.59478586]
#  [-168.84725242  174.93284297]
#  [-175.12381231 -162.49440322]]
